# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\admin\\OneDrive\\Desktop\\3-2\\NLP\\Cleaned_Indian_Food_Dataset.csv",encoding =('ISO-8859-1'),low_memory =False)

# %%
df.head()
# Out:
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                TranslatedIngredients  TotalTimeInMins  \
# 0  1 tablespoon Red Chilli powder,3 tablespoon Gr...               45
# 1   2 teaspoon cashew - or peanuts, 1/2 Teaspoon ...               15
# 2  1 Onion - sliced,1 teaspoon White Urad Dal (Sp...               50
# 3  1/2 teaspoon Turmeric powder (Haldi),1 tablesp...               45
# 4   oil - as per use, 1 tablespoon coriander seed...               30
#
#                 Cuisine                             TranslatedInstructions  \
# 0                Indian  To begin making the Masala Karela Recipe,de-se...
# 1  South Indian Recipes  To make tomato puliogere, first cut the tomato...
# 2  South Indian Recipes  To begin making the Ragi Vermicelli Recipe, fi...
# 3                Andhra  To begin making Gongura Chicken Curry Recipe f...
# 4                Andhra  To make Andhra Style Alam Pachadi, first heat ...
#
#                                                  URL  \
# 0  https://www.archanaskitchen.com/masala-karela-...
# 1  https://www.archanaskitchen.com/spicy-tomato-r...
# 2  https://www.archanaskitchen.com/ragi-vermicell...
# 3  https://www.archanaskitchen.com/gongura-chicke...
# 4  https://www.archanaskitchen.com/andhra-style-a...
#
#                                  Cleaned-Ingredients  \
# 0  salt,amchur (dry mango powder),karela (bitter ...
# 1  tomato,salt,chickpea lentils,green chilli,rice...
# 2  salt,rice vermicelli noodles (thin),asafoetida...
# 3  tomato,salt,ginger,sorrel leaves (gongura),fen...
# 4  tomato,salt,ginger,red chillies,curry,asafoeti...
#
#                                            image-url  Ingredient-count
# 0  https://www.archanaskitchen.com/images/archana...                10
# 1  https://www.archanaskitchen.com/images/archana...                12
# 2  https://www.archanaskitchen.com/images/archana...                12
# 3  https://www.archanaskitchen.com/images/archana...                15
# 4  https://www.archanaskitchen.com/images/archana...                12

# %%
df1=df[['Cleaned-Ingredients','TranslatedInstructions']]

# %%
df1.head()
# Out:
#                                  Cleaned-Ingredients  \
# 0  salt,amchur (dry mango powder),karela (bitter ...
# 1  tomato,salt,chickpea lentils,green chilli,rice...
# 2  salt,rice vermicelli noodles (thin),asafoetida...
# 3  tomato,salt,ginger,sorrel leaves (gongura),fen...
# 4  tomato,salt,ginger,red chillies,curry,asafoeti...
#
#                               TranslatedInstructions
# 0  To begin making the Masala Karela Recipe,de-se...
# 1  To make tomato puliogere, first cut the tomato...
# 2  To begin making the Ragi Vermicelli Recipe, fi...
# 3  To begin making Gongura Chicken Curry Recipe f...
# 4  To make Andhra Style Alam Pachadi, first heat ...

# %%
def process_ingredients(row):
    ingredients = row['Cleaned-Ingredients']
    # Split the ingredients by comma
    ingredient_tokens = ingredients.split(',')
    processed_ingredients = []
    for token in ingredient_tokens:
        # Check if the token has an alternative name in brackets
        if '(' in token and ')' in token:
            # Split the token into main ingredient and alternative name
            main_ingredient, alternative_name = token.split('(', 1)
            # Strip whitespace from both
            main_ingredient = main_ingredient.strip()
            alternative_name = alternative_name.strip(')')
            # Add both to the ingredient list
            processed_ingredients.append(main_ingredient)
            processed_ingredients.append(alternative_name)
        else:
            # If no alternative name, just add the token as it is
            processed_ingredients.append(token.strip())
    return processed_ingredients

# Apply the function to each row of the DataFrame
df['ingredient_list'] = df.apply(process_ingredients, axis=1)

# %%
df.head()
# Out:
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                TranslatedIngredients  TotalTimeInMins  \
# 0  1 tablespoon Red Chilli powder,3 tablespoon Gr...               45
# 1   2 teaspoon cashew - or peanuts, 1/2 Teaspoon ...               15
# 2  1 Onion - sliced,1 teaspoon White Urad Dal (Sp...               50
# 3  1/2 teaspoon Turmeric powder (Haldi),1 tablesp...               45
# 4   oil - as per use, 1 tablespoon coriander seed...               30
#
#                 Cuisine                             TranslatedInstructions  \
# 0                Indian  To begin making the Masala Karela Recipe,de-se...
# 1  South Indian Recipes  To make tomato puliogere, first cut the tomato...
# 2  South Indian Recipes  To begin making the Ragi Vermicelli Recipe, fi...
# 3                Andhra  To begin making Gongura Chicken Curry Recipe f...
# 4                Andhra  To make Andhra Style Alam Pachadi, first heat ...
#
#                                                  URL  \
# 0  https://www.archanaskitchen.com/masala-karela-...
# 1  https://www.archanaskitchen.com/spicy-tomato-r...
# 2  https://www.archanaskitchen.com/ragi-vermicell...
# 3  https://www.archanaskitchen.com/gongura-chicke...
# 4  https://www.archanaskitchen.com/andhra-style-a...
#
#                                  Cleaned-Ingredients  \
# 0  salt,amchur (dry mango powder),karela (bitter ...
# 1  tomato,salt,chickpea lentils,green chilli,rice...
# 2  salt,rice vermicelli noodles (thin),asafoetida...
# 3  tomato,salt,ginger,sorrel leaves (gongura),fen...
# 4  tomato,salt,ginger,red chillies,curry,asafoeti...
#
#                                            image-url  Ingredient-count  \
# 0  https://www.archanaskitchen.com/images/archana...                10
# 1  https://www.archanaskitchen.com/images/archana...                12
# 2  https://www.archanaskitchen.com/images/archana...                12
# 3  https://www.archanaskitchen.com/images/archana...                15
# 4  https://www.archanaskitchen.com/images/archana...                12
#
#                                      ingredient_list
# 0  [salt, amchur, dry mango powder, karela, bitte...
# 1  [tomato, salt, chickpea lentils, green chilli,...
# 2  [salt, rice vermicelli noodles, thin, asafoeti...
# 3  [tomato, salt, ginger, sorrel leaves, gongura,...
# 4  [tomato, salt, ginger, red chillies, curry, as...

# %%
df1=df[['ingredient_list','TranslatedInstructions']]

# %%
df1.iloc[0][0]
# Out:
# ['salt',
#  'amchur',
#  'dry mango powder',
#  'karela',
#  'bitter gourd pavakkai',
#  'red chilli powder',
#  'gram flour',
#  'besan',
#  'onion',
#  'cumin seeds',
#  'jeera',
#  'coriander powder',
#  'turmeric powder',
#  'sunflower oil']

# %%
import pandas as pd



# Extract ingredients from strings and compile into a single list
ingredients_list = [ingredient for ingredient_list in df1['ingredient_list'] for ingredient in ingredient_list]
ingredients_list
# Out:
# ['salt',
#  'amchur',
#  'dry mango powder',
#  'karela',
#  'bitter gourd pavakkai',
#  'red chilli powder',
#  'gram flour',
#  'besan',
#  'onion',
#  'cumin seeds',
#  'jeera',
#  'coriander powder',
#  'turmeric powder',
#  'sunflower oil',
#  'tomato',
#  'salt',
#  'chickpea lentils',
#  'green chilli',
#  'rice',
#  'mustard',
#  'bc belle bhat powder',
#  'dry red chilli',
#  'cashew peanuts',
#  'oilasafoetida',
#  'cumin seeds',
#  'white urad dal',
#  'salt',
#  'rice vermicelli noodles',
#  'thin',
#  'asafoetida',
#  'hing',
#  'mustard seeds',
#  'ghee',
#  'green peas',
#  'matar',
#  'carrot',
#  'curry leaves',
#  'white urad dal',
#  'split',
#  'onion',
#  'lemon',
#  'green chillies',
#  'tomato',
#  'salt',
#  'ginger',
#  'sorrel leaves',
#  'gongura',
#  'fennel seeds',
#  'saunf',
#  'sesame',
#  'gingelly) oil',
#  'cloves garlic',
#  'coriander',
#  'dhania) seeds',
#  'onion',
#  'chicken',
#  'methi seeds',
#  'fenugreek seeds',
#  'dry red chillies',
#  'turmeric powder',
#  'green chillies',
#  'garam masala powder',
#  'tomato',
#  'salt',
#  'ginger',
#  'red chillies',
#  'curry',
#  'asafoetida',
#  'mustard',
#  'chana dal',
#  'onion',
#  'oil',
#  'coriander seeds',
#  'white urad dal',
#  'cashew nuts',
#  'salt',
#  'yellow moong dal',
#  'split',
#  'ginger',
#  'green chilli',
#  'rice',
#  'coriander',
#  'dhania) leaves',
#  'ghee',
#  'asafoetida',
#  'hing',
#  'water',
#  'black peppercorns',
#  'curry leaves',
#  'cumin seeds',
#  'jeera',
#  'mint leaves',
#  'pudina',
#  'sunflower oil',
#  'salt',
#  'tamarind water',
#  'coconut',
#  'mustard seeds',
#  'jaggery',
#  'vellai poosanikai',
#  'ash gourdwhite pumpkin',
#  'curry leaves',
#  'dry red chillies',
#  'coriander',
#  'dhania) seeds',
#  'methi seeds',
#  'fenugreek seeds',
#  'cumin seeds',
#  'jeera',
#  'turmeric powder',
#  'sesame seeds',
#  'til seeds',
#  'sunflower oil',
#  'tomato',
#  'spring onion greens',
#  'hung curd',
#  'greek yogurt',
#  'black beans',
#  'cloves garlic',
#  'rice brown rice',
#  'coriander',
#  'dhania) leaves',
#  'onion',
#  'lemon',
#  'cheddar cheese',
#  'spinach leaves',
#  'palak',
#  'tortillas',
#  'tomato',
#  'salt',
#  'coriander',
#  'dhania) leaves',
#  'idli',
#  'red chilli powder',
#  'tomato ketchup',
#  'onion',
#  'green bell pepper',
#  'capsicum',
#  'mint leaves',
#  'pudina',
#  'turmeric powder',
#  'green chillies',
#  'sunflower oil',
#  'tomato',
#  'salt',
#  'turmeric powder',
#  'red chillies',
#  'spoon oil',
#  'rye',
#  'asafoetida',
#  'cloves garlic',
#  'curry leaves',
#  'cabbage leaves',
#  'tamarind',
#  'cumin seeds',
#  'white urad dal',
#  'tomato',
#  'salt',
#  'cumin powder',
#  'jeera',
#  'pepper',
#  ' pepper',
#  'cloves garlic',
#  'virgin olive oil',
#  'onion',
#  'dry beans',
#  'such cannellini soya beans',
#  'red chilli powder cayenne pepper',
#  'dried oregano',
#  'cheese',
#  'salt',
#  'burger buns',
#  'potato',
#  'aloo) pressure',
#  'tomato',
#  'soy granules',
#  'eggs',
#  'cumin powder',
#  'jeera',
#  'tabasco original sauce',
#  'sunflower oil',
#  'red chilli powder',
#  'cloves garlic',
#  'red chilli flakes',
#  'jalapenos',
#  'onion',
#  'green bell pepper',
#  'capsicum',
#  'wheat bread crumbs',
#  'dried oregano',
#  'salt',
#  'arhar dal',
#  'split toor dal',
#  'tamarind water',
#  'mustard seeds',
#  'asafoetida',
#  'hing',
#  'curry leaves',
#  'cumin seeds',
#  'jeera',
#  'methi seeds',
#  'fenugreek seeds',
#  'sunflower oil',
#  'tomato',
#  'salt',
#  'cumin powder',
#  'jeera',
#  'coriander powder',
#  'bay leaves',
#  'tej patta',
#  'mustard oil',
#  'coriander',
#  'dhania) leaves',
#  'water',
#  'sugar',
#  'cumin seeds',
#  'jeera',
#  'ginger paste',
#  'turmeric powder',
#  'green chillies',
#  'aar maach',
#  'fish) rohu katla fish (cut steaks',
#  'fennel seeds',
#  'saunf',
#  'potato',
#  'aloo) skin',
#  'milk',
#  'red chilli powder',
#  'coriander',
#  'dhania) leaves',
#  'turmeric powder',
#  'salt',
#  'rye',
#  'jaggery',
#  'black urad dal',
#  'split',
#  'curry leaves',
#  'dry red chillies',
#  'onion',
#  'oil',
#  'tamarind paste',
#  'cumin seeds',
#  'green chillies',
#  'ginger',
#  'bay leaf',
#  'tej patta',
#  'coriander',
#  'dhania) leaves',
#  'mint leaves',
#  'pudina',
#  'cloves garlic',
#  'cinnamon stick',
#  'dalchini',
#  'onion',
#  'coriander powder',
#  'eggs',
#  'cloves',
#  'laung',
#  'garam masala powder',
#  'sunflower oil',
#  'coriander',
#  'dhania) leaves',
#  'cucumber grind',
#  'salt',
#  'green',
#  'cumin powder',
#  'curd',
#  'gourd',
#  'salt',
#  'rice flour',
#  'coriander',
#  'dhania) leaves',
#  'onion powder',
#  'sunflower oil the r tots',
#  'flour',
#  'maida',
#  'red chilli flakes',
#  'garlic powder',
#  'potato',
#  'aloo',
#  'dried oregano',
#  'turmeric powder',
#  'ginger',
#  'rice',
#  'ghee',
#  'cinnamon',
#  'fennel',
#  'red chilli powder',
#  'cloves garlic',
#  'carrot',
#  'green beans',
#  'onion',
#  'bay leaf break',
#  'mint leaves',
#  'potatoes',
#  'pepper',
#  'cloves',
#  'coriander seeds',
#  'green chillies',
#  'green peas',
#  'cashew nuts',
#  'salt',
#  'rye',
#  'urad dal',
#  'mint',
#  'coriander',
#  'curry leaves',
#  'amla',
#  'onion',
#  'oil',
#  'chana dal',
#  'bud garlic',
#  'green chillies',
#  'salt',
#  'wheat flour',
#  'cumin powder',
#  'jeera',
#  'ghee on thalipeeth',
#  'coriander',
#  'dhania) leaves',
#  'red chilli powder',
#  'cloves garlic',
#  'gram flour',
#  'besan',
#  'cucumber',
#  'coriander powder',
#  'rice flour',
#  'turmeric powder',
#  'green chillies',
#  'tomato',
#  'salt',
#  'hung curd',
#  'greek yogurt',
#  'stalks spring onion',
#  'bulb greens',
#  'coriander',
#  'dhania) leaves',
#  'tabasco original sauce',
#  'green moong sprouts',
#  'cloves garlic',
#  'pepper',
#  'beetroot',
#  'submarine bread',
#  'subway bread) (flat breads foot s',
#  'salt',
#  'mustard seeds',
#  'coconut',
#  'water',
#  'drumstick',
#  'curry leaves',
#  'dry red chillies',
#  'turmeric powder',
#  'coconut oil',
#  'green chillies',
#  'mango pulp',
#  'puree',
#  'milk cold milk',
#  'ice cubes',
#  'saffron strands',
#  'curd',
#  'badam',
#  'almond',
#  'cardamom powder',
#  'salt',
#  'idli dosa mixture',
#  'coconut',
#  'jaggery',
#  'rice rava',
#  'water',
#  'oil',
#  'cashew nuts',
#  'black cardamom',
#  'badi elaichi',
#  'tomato',
#  'kashmiri red chilli powder',
#  'samosas mini',
#  'green chilli',
#  'ginger',
#  'cardamom',
#  'elaichi) podsseeds',
#  'bay leaf',
#  'tej patta',
#  'cloves cloves',
#  'laung',
#  'black peppercorns',
#  'sugar',
#  'cinnamon stick',
#  'dalchini',
#  'mace',
#  'javitri',
#  'onion',
#  'coriander powder',
#  'turmeric powder',
#  'kasuri methi',
#  'dried fenugreek leaves',
#  'garam masala powder',
#  'sunflower oil',
#  'tomato',
#  'salt',
#  'baguette',
#  'italian',
#  'garlic',
#  'onion',
#  'cheddar cheese',
#  'black pepper powder',
#  'tomato pasta sauce',
#  'spinach leaves',
#  'palak',
#  'butter',
#  'red bell pepper',
#  'capsicum) (',
#  'asafoetida',
#  'hing',
#  'ajwain',
#  'carom seeds',
#  'curry leaves',
#  'onion',
#  'cumin seeds',
#  'jeera',
#  'turmeric powder',
#  'green chillies',
#  'chana dal',
#  'bengal gram dal',
#  'sunflower oil',
#  'salt',
#  'wheat flour',
#  'sev',
#  'pomegranate fruit kernels',
#  'flour',
#  'maida',
#  'green chutney',
#  'coriander mint',
#  'garam masala powder',
#  'red chilli powder',
#  'sweet chutney',
#  'date tamarind',
#  'sugar',
#  'amchur',
#  'dry mango powder',
#  'ghee',
#  'salt',
#  'green beans',
#  'french beans',
#  'rice wine vinegar',
#  'sesame',
#  'gingelly) oil',
#  'cloves garlic',
#  'soy sauce',
#  'thai sweet chilli sauce',
#  'lemon',
#  'peanuts',
#  'moongphali',
#  'baking powder',
#  'water make the dough',
#  'water',
#  'sugar',
#  'vanilla',
#  'flour',
#  'maida',
#  'sesame seeds',
#  'til seeds) white',
#  'sunflower oil',
#  'tomato',
#  'turmeric powder',
#  'salt',
#  'coriander',
#  'dhania) leaves',
#  'fenugreek',
#  'sundkai',
#  'asafoetida',
#  'water',
#  'mustard',
#  'dry red chilli',
#  'curry leaves',
#  'oil',
#  'coriander powder',
#  'arhar dal',
#  'tamarind',
#  'sambar powder',
#  'cumin seeds',
#  'salt',
#  'spinach',
#  'virgin olive oil',
#  'lemon',
#  'pomegranate fruit kernels',
#  'cabbage',
#  'patta gobi muttaikose',
#  'pepper',
#  'salt',
#  'cinnamon powder',
#  'dalchini',
#  'amchur',
#  'dry mango powder',
#  'ghee',
#  'red chilli powder',
#  'green peas',
#  'matar',
#  'water',
#  'green chilli sauce',
#  'cumin seeds',
#  'jeera',
#  'flour',
#  'maida',
#  'garam masala powder',
#  'sunflower oil',
#  'cheese',
#  'baking powder',
#  'britannia',
#  'raspberries',
#  'milk',
#  'salted butter',
#  'baking soda',
#  'sugar',
#  'vanilla',
#  'dark chocolate',
#  'caster sugar',
#  'cocoa powder',
#  'flour',
#  'maida',
#  'ada',
#  'ghee',
#  'sugar',
#  'cardamom powder',
#  'elaichi',
#  'milk full',
#  'salt',
#  'sunflower oil',
#  'asafoetida',
#  'hing',
#  'red chilli powder',
#  'split methi seeds',
#  'methi kuria',
#  'tindora',
#  'dondakaya kovakkai',
#  'lemon',
#  'turmeric powder',
#  'split mustard seeds',
#  'rai kuria',
#  'jaggery',
#  'cloves garlic',
#  'black peppercorns',
#  'curry leaves',
#  'coriander',
#  'dhania) seeds',
#  'onion',
#  'cumin seeds',
#  'jeera',
#  'turmeric powder',
#  'chicken legs',
#  'sunflower oil',
#  'salt',
#  'cardamom',
#  'elaichi) podsseeds',
#  'dry red chillies',
#  'tamarind paste',
#  'kalonji',
#  'onion nigella seeds',
#  'coconut',
#  'mustard seeds',
#  'methi seeds',
#  'fenugreek seeds',
#  'hung curd',
#  'greek yogurt',
#  'ginger',
#  'ghee',
#  'fennel seeds',
#  'saunf',
#  'cinnamon stick',
#  'dalchini',
#  'cloves',
#  'laung',
#  'tomato',
#  'coriander',
#  'dhania',
#  'jackfruit seeds',
#  'kathal',
#  'salt',
#  'tamarind water',
#  'mustard seeds',
#  'asafoetida',
#  'hing',
#  'coconut',
#  'red chilli powder',
#  'cloves garlic',
#  'black peppercorns',
#  'curry leaves',
#  'dry red chillies',
#  'onion',
#  'cumin seeds',
#  'jeera',
#  'coriander',
#  'dhania) seeds',
#  'turmeric powder',
#  'sambar powder',
#  'sunflower oil',
#  'tomato',
#  'turmeric powder',
#  'salt',
#  'ginger',
#  'red chilli powder',
#  'eggsplant',
#  'coriander',
#  'onion',
#  'oil',
#  'coriander powder',
#  'green chillies',
#  'butter',
#  'garam masala powder',
#  'milk',
#  'water',
#  'saffron strands',
#  'tea leaves',
#  'turmeric powder',
#  'salt',
#  'tamarind water',
#  'asafoetida',
#  'jaggery',
#  'mustard',
#  'curry leaves',
#  'dry red chillies',
#  'oil',
#  'mango',
#  'sambar powder',
#  'tomato',
#  'jackfruit seeds',
#  'kathal',
#  'ginger',
#  'tamarind water',
#  'mustard seeds',
#  'coconut',
#  'cloves garlic',
#  'curry leaves',
#  'dry red chillies',
#  'coriander',
#  'dhania) seeds',
#  'cumin seeds',
#  'jeera',
#  'cinnamon stick',
#  'dalchini',
#  'turmeric powder',
#  'cloves',
#  'laung',
#  'kala chana',
#  'brown chickpeas',
#  'salt',
#  'wheat flour',
#  'red bell pepper',
#  'capsicum',
#  'cheese flavoured',
#  'italian',
#  'parsley leaves',
#  'onion',
#  'broccoli',
#  'salt',
#  'makki ka atta',
#  'yellow corn meal flour',
#  'kashmiri red chilli powder',
#  'ajwain',
#  'carom seeds',
#  'methi leaves',
#  'fenugreek leaves',
#  'green chillies',
#  'salt',
#  'mustard seeds',
#  'asafoetida',
#  'hing',
#  'carrot',
#  'curry leaves',
#  'sugar',
#  'lemon',
#  'green bell pepper',
#  'capsicum',
#  'turmeric powder',
#  'green chillies',
#  'cabbage',
#  'patta gobi muttaikose',
#  'sunflower oil',
#  'salt',
#  'wheat flour',
#  'water',
#  'dry yeast',
#  'virgin olive oil',
#  'sugar',
#  'flour',
#  'maida',
#  'tomato',
#  'salt',
#  'mustard seeds',
#  'red chilli powder',
#  'cloves garlic',
#  'dry red chillies',
#  'methi seeds',
#  'fenugreek seeds',
#  'tamarind paste',
#  'turmeric powder',
#  'sunflower oil',
#  'salt',
#  'brown rice',
#  'rosemary',
#  'red chilli flakes',
#  'water',
#  'onion',
#  'garlic',
#  'oil',
#  'oregano',
#  'salt',
#  'wheat flour',
#  'water',
#  'ghee',
#  'salt',
#  'ridge gourd skin',
#  'turai peerkangai',
#  'mustard seeds',
#  'curry leaves',
#  'white urad dal',
#  'split',
#  'dry red chillies',
#  'methi seeds',
#  'fenugreek seeds',
#  'tamarind',
#  'sunflower oil',
#  'salt',
#  'wheat',
#  'dalia godumai rava',
#  'water make pakora batter',
#  'enos fruit salt',
#  'green chilli',
#  'coriander',
#  'dhania) leaves',
#  'ajwain',
#  'carom seeds',
#  'sunflower oil the pakoras',
#  'gram flour',
#  'besan',
#  'onion',
#  'cumin seeds',
#  'jeera',
#  'turmeric powder',
#  'sunflower oil',
#  'salt',
#  'wheat flour',
#  'hung curd',
#  'greek yogurt',
#  'ginger',
#  'ghee',
#  'paneer',
#  'chaat masala powder',
#  'cloves garlic',
#  'gram flour',
#  'besan',
#  'onion',
#  'lemon',
#  'coal giving smoked flavour',
#  'green bell pepper',
#  'capsicum',
#  'mint leaves',
#  'pudina',
#  'turmeric powder',
#  'kasuri methi',
#  'dried fenugreek leaves',
#  'garam masala powder',
#  'salt',
#  'jasmine rice',
#  'eggs fork',
#  'mozzarella cheese',
#  'virgin olive oil',
#  'onion',
#  'parsley leaves',
#  'sweet corn',
#  'parmesan cheese',
#  'flour',
#  'maida',
#  'wheat bread crumbs',
#  'butter',
#  'sunflower oil',
#  'tomato',
#  'salt',
#  'cumin powder',
#  'jeera',
#  'red chillies',
#  'fish fillet basa',
#  'paprika powder',
#  'coriander',
#  'dhania) leaves',
#  'chicken stock',
#  'cloves garlic',
#  'carrot',
#  'virgin olive oil',
#  'onion',
#  'lemon',
#  'baby potatoes',
#  'black pepper powder',
#  'coconut milk',
#  'clamps',
#  'prawns',
#  'salt',
#  'water',
#  'cloves garlic',
#  'soy sauce',
#  'white vinegar',
#  'green bell pepper',
#  'capsicum',
#  'tomato ketchup',
#  'onion',
#  'dry red chillies',
#  'chilli flakes',
#  'black pepper powder',
#  'hakka noodles',
#  'red chilli sauce',
#  'sunflower oil',
#  'tomato',
#  'salt',
#  'ginger',
#  'bay leaf',
#  'tej patta',
#  'paneer',
#  'potato',
#  'aloo',
#  'red chilli powder',
#  'dry red chilli',
#  'sugar',
#  'cumin seeds',
#  'jeera',
#  'panch phoran masala',
#  'turmeric powder',
#  'sunflower oil',
#  'salt',
#  'corn flour',
#  'nutralite cheesy garlic mayo',
#  'mozzarella cheese',
#  'nutralite garlic oregano pan roasting',
#  'broccoli florets',
#  'wheat bread crumbs',
#  'salt',
#  'kasundi mustard sauce',
#  'kalonji',
#  'onion nigella seeds',
#  'green chilli',
#  'mustard oil',
#  'mustard seeds',
#  'potato',
#  'aloo',
#  'red chilli powder',
#  'sugar',
#  'onion',
#  'cumin seeds',
#  'jeera',
#  'turmeric powder',
#  'mooli mullangi',
#  'radish',
#  'salt',
#  'coriander',
#  'tamarind water',
#  'asafoetida',
#  'mustard',
#  'curry leaves',
#  'dry red chilli',
#  'chakundar',
#  'sesame oil',
#  'arhar dal',
#  'sambar powder',
#  'salt',
#  'wheat flour',
#  'spinach',
#  'red chilli powder',
#  'sunflower oil rotis',
#  'cumin seeds',
#  'jeera',
#  'parangikai pumpkin',
#  'red preferably',
#  'coriander powder',
#  'water dough',
#  'turmeric powder',
#  'salt',
#  'ginger',
#  'eggs',
#  'coconut',
#  'jaggery',
#  'cloves garlic',
#  'dry red chilli',
#  'coriander',
#  'dhania) leaves',
#  'coriander',
#  'dhania) seeds',
#  'onion',
#  'poppy seeds',
#  'badam',
#  'almond',
#  'sesame seeds',
#  'til seeds',
#  'sunflower oil',
#  'tomato',
#  'salt',
#  'ginger',
#  'asafoetida',
#  'hing',
#  'coriander',
#  'dhania) leaves',
#  'ajwain',
#  'carom seeds',
#  'cloves garlic',
#  'water',
#  'gram flour',
#  'besan',
#  'baking soda',
#  'onion',
#  'coconut milk',
#  'turmeric powder',
#  'green chillies',
#  'sunflower oil',
#  'salt',
#  'ginger',
#  'sunflower oil',
#  'asafoetida',
#  'hing',
#  'mustard seeds',
#  'sesame',
#  'gingelly) oil',
#  'water',
#  'curry leaves',
#  'rice flour',
#  'green chillies',
#  'white urad dal',
#  'spring onion greens',
#  'cumin powder',
#  'jeera',
#  'carrot',
#  'onion',
#  'black pepper powder',
#  'green chillies',
#  'sunflower oil',
#  'eggs noodles tossed oil',
#  'salt',
#  'soy sauce',
#  'white pepper powder',
#  'rice',
#  'chinese spice powder',
#  'red chilli powder',
#  'garlic',
#  'lemon',
#  'classic mayonnaise',
#  'with eggs',
#  'sweet spicy red chilli sauce',
#  'tomato chilli sauce',
#  'boneless chicken',
#  'ginger',
#  'spring onion',
#  'bulb greens',
#  'tomato ketchup',
#  'vinegar',
#  'green bell pepper',
#  'capsicum',
#  'red chilli sauce',
#  'turmeric powder',
#  'salt',
#  'tomato take',
#  'rice',
#  'ghee',
#  'capsicum',
#  'green) red yellow',
#  'red chilli powder',
#  'lentil sugar',
#  'ginger garlic paste',
#  'coriander',
#  'bay leaf',
#  'onion',
#  'coriander powder',
#  'tofu',
#  'green chillies',
#  'cumin seeds',
#  'garam masala powder',
#  'tomato',
#  'pav bhaji masala',
#  'salt',
#  'ginger',
#  'french bread rye bread',
#  'coriander',
#  'dhania) leaves',
#  'paneer',
#  'rocket leaves salad leaves the sandwich',
#  'cloves garlic',
#  'onion',
#  'green bell pepper',
#  'capsicum',
#  'potato',
#  'aloo',
#  'tomato',
#  'salt',
#  'red wine vinaigrette',
#  'cloves garlic',
#  'virgin olive oil',
#  'onion',
#  'black pepper powder',
#  'dijon mustard',
#  'cane sugar',
#  'dried oregano',
#  'salt',
#  'coriander',
#  'dhania) leaves',
#  'coconut',
#  ...]

# %%
ingredients_list=sorted(set(ingredients_list))
ingredients_list
# Out:
# ['',
#  ' ) plus cherries stems',
#  ' * es',
#  ' after ing',
#  ' b',
#  ' banana replace eggs',
#  ' based on its strength',
#  ' black pepper',
#  ' brush prep',
#  ' byadgi : guntur',
#  ' can',
#  ' can also be used not vegan',
#  ' canned',
#  ' canola vegetable oil',
#  ' case you intend not pineapple juice',
#  ' change water everyday',
#  ' coffee beans',
#  ' consistency',
#  ' cooled',
#  ' corn meal',
#  ' depending on the pungency',
#  ' diameter',
#  ' dried parsley used',
#  ' dried tarragon used',
#  ' es',
#  ' fillet',
#  ' flavour ',
#  ' flour',
#  ' gram',
#  ' guavas them grinder',
#  ' kids crowd sweet tooth',
#  ' large bajji chilli green bell peppers',
#  ' large packs',
#  ' lemon size',
#  ' less based on the spice level desired',
#  ' make dosa',
#  ' making the paste the amount mustard used ',
#  ' millet',
#  ' ml',
#  ' months above',
#  ' needed',
#  ' not season',
#  ' number pan',
#  ' nutmeg',
#  ' only',
#  ' oz',
#  ' packet',
#  ' pearl millet',
#  ' pepper',
#  ' per preference',
#  ' per spice preference',
#  ' preferably',
#  ' preference',
#  ' quantity ',
#  ' recipe portions',
#  ' reduce ',
#  ' rice',
#  ' rice variety',
#  ' ripen totapuri cultivar',
#  ' sheets',
#  ' size',
#  ' slices',
#  ' spice',
#  " spinach you don'have",
#  ' strand',
#  ' strips',
#  ' such are needed',
#  ' sugar',
#  ' suit spice levels',
#  ' sweetness mangoes',
#  ' th',
#  ' than ',
#  ' the amount ',
#  ' the heat the chillies',
#  ' the number chillies spice level',
#  ' the tartness mangoes',
#  ' tolerance',
#  ' tuna from standard tin',
#  ' using mortar pestle',
#  ' virgin',
#  ' vivatta wheat flour chakki atta',
#  ' whistles',
#  ' you can an oil spray',
#  ' you can grate nutmeg directly on the filling',
#  ' you like spicy',
#  '%',
#  '(',
#  '(amul',
#  '(or milk',
#  '(or nondairy',
#  ')',
#  ') sour',
#  'aachi fish masala',
#  'aam papad',
#  'aamras',
#  'aar maach',
#  'achari masala',
#  'achari mayo',
#  'achari mayo drizzling on top',
#  'achari mayo tikki',
#  'acorn squash',
#  'ada',
#  'adobo sauce',
#  'aerated water',
#  'agar agar',
#  'agar agar gelatin',
#  'agar agar strands',
#  'agathi keerai',
#  'agave nectar',
#  'agavemaple syrup',
#  'ajwain',
#  'alfalfa powder',
#  'alfalfa sprouts',
#  'alkanet) (infuse heated oil',
#  'alkanet) infuse heated oil',
#  'alkanet) infused oil',
#  'almond',
#  'almond butter',
#  'almond butter peanut butter',
#  'almond essence',
#  'almond meal',
#  'almond milk',
#  'almond milk (badam milk',
#  'almond milk (badam milk frothed',
#  'almond milk (badam milk unsweetened',
#  'almond milk (badam milk water',
#  'almond milk water',
#  'almond oil',
#  'almond pistachios',
#  'almond silver',
#  'almond) ( smoked',
#  'almond) (can be substituted other nuts',
#  'almond) (grind almonds mixer grinder speed',
#  'almond) (preferably ',
#  'almond) a',
#  'almond) flaked',
#  'almond) flaxes',
#  'almond) ground powder',
#  'almond) light',
#  'almond) macadamia nuts',
#  'almond) paste',
#  'almond) pistachios',
#  'almond) pistachois will also do',
#  'almond) pound',
#  'almond) roast ground',
#  'almond) salted',
#  'almond) silvered',
#  'almond) skin',
#  'almond) soak water the skin',
#  'almond) walnuts',
#  'almonds',
#  'almonds cashew nuts pistachios',
#  'almonds cashewnuts',
#  'almonds pistachios',
#  'almonds soak',
#  'aloe vera',
#  'aloo',
#  'aloo bhujia',
#  'aloo tikki',
#  'aloo) (or sweet potato',
#  'aloo) a the skin (do not boil them too soft',
#  'aloo) baby potatoes',
#  'aloo) banana',
#  'aloo) barrel shape',
#  'aloo) bitesize',
#  'aloo) boiled',
#  'aloo) cm cubes',
#  'aloo) cubes',
#  'aloo) fingers',
#  'aloo) firm',
#  'aloo) fries',
#  'aloo) large cubes',
#  'aloo) paper',
#  'aloo) pealed',
#  'aloo) pressure',
#  'aloo) salt water',
#  'aloo) skin',
#  'aloo) skin pound',
#  'aloo) straws',
#  'aloo) the potatoes',
#  'aloo) the skin large cubes',
#  'also works',
#  'alu bukhara',
#  'amaranth flour',
#  'amaranth flour) binding',
#  'amaranth leaves',
#  'amaranth seeds',
#  'amchoor',
#  'amchoor powder',
#  'amchoor powder per requirement',
#  'amchur',
#  'amchur lemon',
#  'amchur powder',
#  'amla',
#  'amla size',
#  'amtekai',
#  'amtekai) (ambade',
#  'amul',
#  'amul brand',
#  'anardana powder',
#  'and ',
#  'aniseed',
#  'any local variety',
#  'any variety',
#  'appe midi',
#  'apple',
#  'apple (',
#  'apple chickoo',
#  'apple cider vinegar',
#  'apple cider vinegar vinegar',
#  'apple cider vinegar white vinegar',
#  'apple cored',
#  'apple cored spiralized noodles',
#  'apple crescent shaped',
#  'apple gourd',
#  'apple juice',
#  'apple julienne',
#  'apple matchstickthin',
#  'apple vodka',
#  'apples',
#  'apples apples',
#  'apples cored',
#  'applewithout',
#  'apricots',
#  'apricots dried',
#  'apricots drieds',
#  'arabic',
#  'arabic leaves',
#  'arabic now',
#  'arabica',
#  'aralu',
#  'arbi',
#  'arbi) destemmed',
#  'arbi) leaves a tender stems',
#  'arbi) skin',
#  'arbi) tho',
#  'arbi)like fries',
#  'arborio rice',
#  'arhar dal',
#  'arhar dal moong dal',
#  'arhar dal soak',
#  'arisithipli',
#  'around beets',
#  'around gm',
#  'arrowroot flour',
#  'arrowroot flour corn flour',
#  'artichokes',
#  'artichokes tinned artichokes',
#  'arugula leaves',
#  'arugula leaves roots',
#  'asafetida',
#  'asafoetida',
#  'ash gourd chips',
#  'ash gourdwhite pumpkin',
#  'ash gourdwhite pumpkin) de skinned',
#  'ash gourdwhite pumpkin) seeds skin',
#  'ash gourdwhite pumpkin) skin',
#  'asian',
#  'asian sea bass',
#  'asian style',
#  'asparagus',
#  'asparagus stem',
#  'assam tea leaves',
#  'assorted colors',
#  'at ',
#  'atta',
#  'aubergine',
#  'avarekai',
#  'avarekalu lilva beans',
#  'avarekalu lilva beans field beans',
#  'avarekalu lilva beans pressure',
#  'avarekalu lilva beans skin',
#  'avarekalu lilva beans stringed',
#  'avocado',
#  'avocado bite just before',
#  'avocado fork',
#  'avocado fully ripe',
#  'avocado pulped',
#  'avocado ripe',
#  'avocado ripen',
#  'avocado ripened',
#  'avocado skin',
#  'avocados',
#  'avocados ripe',
#  'avocados ripened',
#  'avrekalu',
#  'azuki',
#  'baby corn',
#  'baby corn (if using',
#  'baby corn approximately',
#  'baby corn baby corn',
#  'baby corn be',
#  'baby corn take',
#  'baby potatoes',
#  'baby potatoes potato',
#  'baby potatoes quatered',
#  'baby potatoes skin',
#  'baby spinach',
#  'baby spinach salad leaves',
#  'baby spinach tore',
#  'bacon',
#  'bacon smoked',
#  'badam',
#  'badam essence',
#  'badam milk coconut milk (ly cted',
#  'badam oil',
#  'badam powder',
#  'badam) a',
#  'badam) almonds',
#  'badam) pista cashews',
#  'badam) pound',
#  'badam) walnuts',
#  'badi',
#  'badi elaichi',
#  'badi hari mirch',
#  'bael fruit',
#  'bagel',
#  'baguette',
#  'baguette wheat',
#  'baileys irish',
#  'baingan eggsplant',
#  'baingan eggsplant) ( variety',
#  'baingan eggsplant) (crown each',
#  'baingan eggsplant) (cut slices',
#  'baingan eggsplant) (into ',
#  'baingan eggsplant) (use smer brinjals elevated ',
#  'baingan eggsplant) cm cubes',
#  'baingan eggsplant) destemmed',
#  'baingan eggsplant) diagonal',
#  'baingan eggsplant) dices',
#  'baingan eggsplant) from top stuffing',
#  'baingan eggsplant) green seedless variety',
#  'baingan eggsplant) make',
#  'baingan eggsplant) mm (lengthwise',
#  'baingan eggsplant) ness',
#  'baingan eggsplant) purple',
#  'baingan eggsplant) quatered',
#  'baingan eggsplant) salt water',
#  'baingan eggsplant) stalks',
#  'baingan eggsplant) three',
#  'baingan eggsplant)(use the regular eggsplant not the used baingan bhartha',
#  'bajji variety (light green s',
#  'bajra',
#  'bajra dosa batter',
#  'bajra flour',
#  'baked beans',
#  'baked beans can',
#  'baked beans tin',
#  'baking powder',
#  'baking powder eggs',
#  'baking powder heaped',
#  'baking soda',
#  'baking soda generous',
#  'baking soda heaped',
#  'balsamic vinegar',
#  'balsamic vinegar red wine vinaigrette',
#  'bamboo shoots',
#  'banana',
#  'banana boil',
#  'banana cubes',
#  'banana dices',
#  'banana flower',
#  'banana leaf',
#  'banana leaf cook',
#  'banana leaf line the steamer',
#  'banana leaf toss heat them squares remove the stem',
#  'banana leaf wrap the fish',
#  'banana leaves cook on low flame',
#  'banana leaves steamer put',
#  'banana skin',
#  'banana stem',
#  'banana stem butter milk',
#  'banana stem buttermilk',
#  'banana stem dices',
#  'banana stem dices buttermilk',
#  'banana stem outer layer',
#  'banana stem skin',
#  'banana stemand',
#  'bananas',
#  'bananas caramelised',
#  'bananas cubes',
#  'bananas diagonal',
#  'bananas fork',
#  'bananas fully ripe',
#  'bananas heaped',
#  'bananas nendra variety',
#  'bananas ripe',
#  'bananas robusta variety',
#  'bananas slice top',
#  'bananas spotty',
#  'bananas the elaichi banana variety',
#  'bangada fish',
#  'barbeque masala',
#  'barbeque sauce',
#  'barbeque sauce bottle jerk barbecue sauce',
#  'barley',
#  'barley flour',
#  'barnyard millet',
#  'barnyard millet variety',
#  'barramundiasian sea bass',
#  'basa fish',
#  'basa fish bless skinless',
#  'basa fish fillet',
#  'basa fish fillets',
#  'basa fish finger length',
#  'basa fish salmon white firm fleshed fish',
#  'basella',
#  'basil',
#  'basil leaves',
#  'basil leaves chiffonade',
#  'basil leaves dried',
#  'basil leaves dried basil',
#  'basil leaves dry',
#  'basil leaves ground paste',
#  'basil leaves kaffir lime leaves',
#  'basil leaves leaves',
#  'basil leaves loosely packed',
#  'basil leaves oregano',
#  'basil leaves prepared earlier',
#  'basil leaves rolled',
#  'basil leaves sniped',
#  'basil leaves take out the stem',
#  'basil leaves the curry',
#  'basil leaves y',
#  'basil pesto',
#  'basil pesto basil pesto',
#  'basil powder oregano',
#  'basmati rice',
#  'basmati rice drain the water',
#  'basmati rice enough water',
#  'basmati rice fragrant rice',
#  'basmati rice gobindo bhog rice',
#  'basmati rice govind bhog rice',
#  'basmati rice grain',
#  'basmati rice grain rice',
#  'basmati rice ground',
#  'basmati rice hour',
#  'basmati rice least',
#  'basmati rice min',
#  'basmati rice mins',
#  'basmati rice soak',
#  'basmati rice spices infused water (spices include cinnamon',
#  'basmati rice white rice; we can substitute this brown rice',
#  'bathua leaves',
#  'batua',
#  'bay leaf',
#  'bay leaf break',
#  'bay leaf break take',
#  'bay leaves',
#  'bay leaves bay leaves',
#  'bc belle bhat powder',
#  'bean paste',
#  'bean sprouts',
#  'beef',
#  'beer',
#  'beetroot',
#  'beetroot centimeter',
#  'beetroot dices',
#  'beetroot greens',
#  'beetroot juice',
#  'beetroot juiced',
#  'beetroot spiralized noodles',
#  'beetroots',
#  'bengal gram dal',
#  'bengal gram dal) (for hour',
#  'bengal gram dal) atleast',
#  'bengal gram dal) fro',
#  'bengal gram dal) ground',
#  'bengal gram dal) hour',
#  'bengal gram dal) least',
#  'bengal gram dal) min',
#  'bengal gram dal) mins',
#  'bengal gram dal) split',
#  'ber stems',
#  'besan',
#  'besan) (besan',
#  'besan) besan',
#  'besan) cardamom powder â\x80\x93 tsp',
#  'besan) dry',
#  'besan) handwa flour mix',
#  'besan) salt',
#  'best french bread',
#  'betel leaves',
#  'betel nut',
#  'bhagar flour',
#  'bhaja masala',
#  'bhakarwdis',
#  'bhang paste',
#  'bhetki fish',
#  'bhetki fish fillets',
#  'bhindi',
#  'bhindiokravendaikkai',
#  'bhut jolokia',
#  'bilimbi',
#  'bimbla',
#  'bird lime',
#  'birds eye chilli',
#  'birds eye chilli) regular green chillies',
#  "birds eye chilli)(if you don'find birds eye chillies",
#  'biryani masala',
#  'biryani masala powder',
#  'bisi bele bhat spice powder',
#  'bisleri fonzo the bubbly mango drink',
#  'bitter gourd',
#  'bitter gourd after removing seeds',
#  'bitter gourd pavakkai',
#  'bitter gourd pavakkai) cylindrical',
#  'bitter gourd pavakkai) de skinned',
#  'bitter gourd pavakkai) dices (remove excess seeds from inside',
#  'bitter gourd pavakkai) scraped',
#  'bitter gourd pavakkai) seeds',
#  'bitter gourd pavakkai) tender',
#  'bitter sweet chocolate',
#  'black beans',
#  'black beans canned',
#  'black beans sauce',
#  'black cardamom',
#  'black chilli powder',
#  'black cumin',
#  'black currant ice',
#  'black eyed beans',
#  'black gram',
#  'black gram soak cook till becomes soft',
#  'black gram sprouted',
#  'black grapes',
#  'black grapes juice',
#  'black olives',
#  'black olives both green black',
#  'black pepper',
#  'black pepper corns',
#  'black pepper corns forr',
#  'black pepper corns ground',
#  'black pepper grind',
#  'black pepper powder',
#  'black pepper powder black pepper powder',
#  'black pepper powder cracked',
#  'black pepper powder grind',
#  'black pepper powder ground',
#  'black pepper powder paprika',
#  'black pepper powder pound',
#  'black pepper powder red chilli powder',
#  'black pepper powder wise',
#  'black pepper powderblack pepper powder',
#  'black peppercorns',
#  'black peppercorns cracked',
#  'black peppercorns ground',
#  'black peppercorns mortar pestle',
#  'black peppercorns pound',
#  'black peppercorns thawed',
#  'black peppercorns y',
#  'black peppers',
#  'black plum',
#  'black raisins',
#  'black rice',
#  'black rice seasd salt',
#  'black salt',
#  'black salt salt',
#  'black salt white salt',
#  'black sesame seeds',
#  'black sesame seeds sprinkling',
#  'black sesame seeds white sesame seeds',
#  'black soy beans',
#  'black tea bag',
#  'black tea leaves',
#  'black urad dal',
#  'black urad dal ground make atta',
#  'black variety',
#  'blackberries berries',
#  'blackberries other berries',
#  'bless',
#  'bless) cubes',
#  'blueberries',
#  'blueberries dry',
#  'blueberries locy available berries',
#  'blueberries locy available berry',
#  'blueberries other berry season',
#  'blueberry jam',
#  'bocconcini cheese halves',
#  'boiled eggs',
#  'boiled peanuts',
#  'bok choy',
#  'bok choy heads',
#  'boneless chicken',
#  'boneless chicken (',
#  'boneless chicken boneless chicken â\x80\x93 gms',
#  'boneless chicken breasts',
#  'boneless chicken cubes',
#  'boneless chicken miced',
#  'boneless chicken uniform',
#  'boondi',
#  'boondi kara boondi',
#  'boondi masala',
#  'boondi masala boondi',
#  'boondi sev',
#  'boondi spicy',
#  'botis golden finger fryums',
#  'bottle gourd',
#  'bourbon',
#  'bourbon biscuits',
#  'bourbon biscuits other biscuits',
#  'bournville rich cocoa from india works fantastic',
#  'brahmi leaves',
#  'branch coriander',
#  'brandy',
#  'bread',
#  'bread crumbs',
#  'bread cubes',
#  'breads',
#  'brie cheese',
#  'brinjal',
#  'brinjals',
#  'britannia',
#  'britannia cheese asli pepper',
#  'britannia cheese block',
#  'britannia cheese classic',
#  'britannia cheese cubes',
#  'britannia cheese four pepper tango',
#  'britannia cheese garlic',
#  'britannia cheese mexican chilli',
#  'britannia cheese peppy pizza',
#  'britannia cheese slice',
#  'britannia cheezza',
#  'broad beans',
#  'broad beans) st cut.',
#  'broccoli',
#  'broccoli bite florets',
#  'broccoli cauliflower florets',
#  'broccoli florets',
#  'broccoli florets approximately',
#  'broccoli florets blitzed',
#  'broccoli flowerets',
#  'broccoli smer',
#  'broccoli smer florets',
#  'broccoli stems',
#  'broccoli tiny florets',
#  'broccolis',
#  'brown cardamom',
#  'brown chickpeas',
#  'brown chickpeas) moong beans',
#  'brown chickpeas) over night',
#  'brown chickpeas) pressure till',
#  'brown chickpeas) sprouted',
#  'brown chickpeas) you get the green variety',
#  'brown rice',
#  'brown rice beforehand',
#  'brown rice flakes',
#  'brown rice poha',
#  'brown sugar',
#  'brussel sprouts',
#  'buckwheat flour',
#  'bud',
#  'bud garlic',
#  'bud garlic paste',
#  'buds garlic',
#  'buds garlic finely',
#  'bulb greens',
#  'bulb greens) (including greens bulbs',
#  'bulb greens) (white greens',
#  'bulb greens) (white top part',
#  'bulb greens) both green white',
#  'bulb greens) bulbs',
#  'bulb greens) bunch',
#  'bulb greens) green bulbs',
#  'bulb greens) leaves',
#  'bulb greens)(or regular onion',
#  'bulb greens)with leaves',
#  'bulb greens)with the bulb leaves kept separate',
#  'bulgur wheat',
#  'bulgur wheat organic',
#  'bunch arugula leaves',
#  'burger buns',
#  'burger buns masala buns',
#  'burger buns mini',
#  'burger buns sliders',
#  'burger buns wheat',
#  'but normal can be used)',
#  'butter',
#  'butter apply on bread',
#  'butter apply on pinwheels',
#  'butter baking',
#  'butter baste',
#  'butter brushing',
#  'butter clarified',
#  'butter coconut butter',
#  'butter coconut oil',
#  'butter cold',
#  'butter cold divided',
#  'butter cold pea',
#  'butter cold unsalted',
#  'butter cooled',
#  'butter cubes',
#  'butter divided',
#  'butter ghee',
#  'butter ghee brushing',
#  'butter gheeoil',
#  'butter grease',
#  'butter grease the pan',
#  'butter grease the tintray',
#  'butter grease waffle iron',
#  'butter greasing',
#  'butter greasing naan',
#  'butter greasing the baking dish',
#  'butter greasing the pan',
#  'butter grilling',
#  'butter have used salted butter',
#  'butter loni',
#  'butter make pancakes',
#  'butter oil',
#  'butter oil grease',
#  'butter oil mixed',
#  'butter oil pancakes',
#  'butter oil the filling',
#  'butter olive oil',
#  'butter olive oil brushing the rotis',
#  'butter olive oil grease',
#  'butter on the naans',
#  'butter pan',
#  'butter pea',
#  'butter per sandwich',
#  'butter plus',
#  'butter plus pan',
#  'butter ricotta cheese',
#  'butter roasting the pizza base',
#  'butter room temprature',
#  'butter salted',
#  'butter salted unsalted',
#  'butter sandwich',
#  'butter sizzling',
#  'butter some finishing',
#  'butter stick',
#  'butter temperature be kept cold',
#  'butter the kulchas',
#  'butter the toast',
#  'butter toasting',
#  'butter toasting pita',
#  'butter toasting the bread',
#  'butter toasting the buns',
#  'butter toasting the burger buns',
#  'butter unsalted',
#  'butter vegan version coconut oil',
#  'butter vegetable oil',
#  'butterapproximately',
#  'butterbutter',
#  'buttermilk',
#  'buttermilk amsul',
#  'buttermilk cold',
#  'buttermilk sour',
#  'buttermilk strained remove lumps',
#  'butternut squash seeded',
#  'butterof butter',
#  'butterscotch chips',
#  'butterscotch chips almonds',
#  'butterscotch ice',
#  'button crimini variety',
#  'button mushroom',
#  'button mushrooms',
#  'button mushrooms (you can alternatively combination vegetables like beans',
#  'button mushrooms cremini mushrooms',
#  'button mushrooms destemmed',
#  'button mushrooms large',
#  'button mushrooms large portobello mushroom',
#  'button mushrooms mushroom',
#  'button mushrooms portabello mushrooms',
#  'button mushrooms sautÃ©ed',
#  'button mushrooms shopped',
#  'button mushrooms stem',
#  'byadagi chilli powder',
#  'byadagi dried chillies',
#  'byadagi dried chillies water',
#  'byadagi dried chillies you can kashmiri chillies red chillies)',
#  'c',
#  'cabbage',
#  'cabbage leaves',
#  'cabbage spoon',
#  'cajun spice mix',
#  'cajun spice mix chutney podi sprinkling on top',
#  'cake candy s',
#  'cake candy s) (preferably',
#  'cake candy s) decorate',
#  'cake candy s) decorating',
#  'cake mix used pillsbury vanilla cake mix',
#  'can bamboo',
#  'can be substituted smoked paprika',
#  'can condensed milk',
#  'can using oregano',
#  'candied orange',
#  'candy sugar',
#  'cane sugar',
#  'cane sugar coconut sugar',
#  'canned',
#  'canned beans',
#  'canned black beans',
#  'canned cherries',
#  'canned cherries available cherries',
#  'canned cherries garnsh',
#  'canned storebought mushrooms',
#  'canned tuna',
#  'canola oil',
#  'canola oil flavorless oil',
#  'canola oil olive oil',
#  'canola oil pan masoor dal fritters',
#  'cape gooseberries husk',
#  'capers',
#  'capsicum',
#  'capsicum) (',
#  'capsicum) ( each',
#  'capsicum) (or other vegetables that can be stir ',
#  'capsicum) bitesize',
#  'capsicum) colour',
#  'capsicum) cubes',
#  'capsicum) diagonal',
#  'capsicum) diamond',
#  'capsicum) fire',
#  'capsicum) green',
#  'capsicum) green capsicum',
#  'capsicum) julienne',
#  'capsicum) jullienes',
#  'capsicum) large squares',
#  'capsicum) larger',
#  'capsicum) red',
#  'capsicum) red bell peppers',
#  'capsicum) red yellow',
#  'capsicum) smer',
#  'capsicum) squares',
#  'capsicum) stir',
#  'capsicum) yellow',
#  'capsicum)lengthwise',
#  'caramel sauce',
#  'caramelize',
#  'cardamom',
#  'cardamom break',
#  'cardamom crush',
#  'cardamom grind',
#  'cardamom powder',
#  'cardamom powder grind',
#  'carom seeds',
#  'carom seeds) (shahi jeera',
#  'carom seeds) between palms',
#  'carom seeds) cumin seeds',
#  'carom seeds) pound',
#  'carom seeds) powder',
#  'carom seeds) sesame seeds',
#  'carrot',
#  'carrot approximately â\x80\x9d',
#  'carrot beans peas',
#  'carrot bitesize',
#  'carrot cake recipe leftover',
#  'carrot carrot',
#  'carrot centimetre cubes',
#  'carrot circles',
#  'carrot coins',
#  'carrot cubes',
#  'carrot dices',
#  'carrot finger coins',
#  'carrot julianne',
#  'carrot julienne',
#  'carrot matchsticks',
#  'carrot ness',
#  'carrot pelled',
#  'carrot red',
#  'carrot skin',
#  'carrot spiralized noodles',
#  'carrot sticks',
#  'carrot veticy',
#  'carrotinto',
#  'carrotor',
#  'cashew',
#  'cashew nuts',
#  'cashew nuts approximately',
#  'cashew nuts cashew nuts',
#  'cashew nuts decoration',
#  'cashew nuts ghee',
#  'cashew nuts ghee ed',
#  'cashew nuts glass water',
#  'cashew nuts ground',
#  'cashew nuts ground paste',
#  'cashew nuts ground smooth paste',
#  'cashew nuts ground smooth paste water',
#  'cashew nuts hour minimum',
#  'cashew nuts least',
#  'cashew nuts paste',
#  'cashew nuts peanuts',
#  'cashew nuts soak water grind',
#  'cashew nuts split',
#  'cashew nuts unsalted',
#  'cashew nuts water',
#  'cashew nuts water salt',
#  'cashew peanuts',
#  'cashews',
#  'cashews almonds',
#  'cashews ground',
#  'cashews ground paste',
#  'cashews soak water',
#  'cashews some',
#  'cashews water',
#  'cassia',
#  'cast coriander',
#  'caster sugar',
#  'caster sugar a',
#  'caster sugar brown sugar',
#  'caster sugar divided',
#  'caster sugar garnsih',
#  'caster sugar superfine',
#  'cauliflower',
#  'cauliflower leaves',
#  'cawanprash',
#  'cayenne pepper',
#  'cayenne pepper ground',
#  'cayenne pepper red chilli powder',
#  'celery',
#  'celery between the palm',
#  'celery stalks',
#  'celery stick',
#  'cereal',
#  'chaat masala powder',
#  'chaat masala powder powder',
#  'chaat masala powder the end',
#  'chai masala',
#  'chakra flowers',
#  'chakundar',
#  'chamomile tea brewed',
#  'champagne sparkling wine',
#  'chana dal',
#  'chana lentils',
#  'chana masala powder',
#  'chana stock',
#  'chandi ka vark',
#  'chandi ka vark) edible',
#  "chandi'work eater",
#  'char magaz',
#  'charcoal',
#  'charcoal dum',
#  'charcoal piece',
#  'charcoal smoke',
#  'charcoal smoking',
#  'chavli',
#  'chayote',
#  'chayote skin',
#  'chayote squash',
#  'chayote squash) cored',
#  'cheddar cheese',
#  'cheddar cheese aged',
#  'cheddar cheese cheese',
#  'cheddar cheese cubes',
#  'cheddar cheese mexican cheese',
#  'cheddar cheese mozzarella cheese',
#  'cheddar cheese paneer',
#  'cheddar cheese sharp',
#  'cheddar cheese topping',
#  'cheddar mexican cheese',
#  'cheddar parmesan',
#  'cheese',
#  'cheese (flavored',
#  'cheese (use britannia',
#  "cheese britannia'classic cheese z",
#  'cheese chaat masala powder',
#  'cheese cheese',
#  'cheese cheese cheese',
#  'cheese crumble',
#  'cheese cubes',
#  'cheese flavored like jalepeno peppers works great',
#  'cheese flavoured',
#  'cheese frosting',
#  'cheese over the bread',
#  'cheese pepper',
#  'cheese pepper flavour prefered',
#  'cheese per tasete',
#  'cheese philadelphia)',
#  'cheese plus topping',
#  'cheese processed',
#  'cheese processed chees',
#  'cheese slice',
#  'cheese soft paneer',
#  'cheese you can do take paneer salt grind mixer',
#  'cheese you find difficult get',
#  'cheese)',
#  'cheesehua pepper powder',
#  'cheetos',
#  'chenna',
#  'cherries',
#  'cherries (or fruits whipped',
#  'cherries dried',
#  'cherries stem',
#  'cherries strawberries',
#  'cherry compote',
#  'cherry preserve jam glazing',
#  'cherry tomato',
#  'cherry tomato (or large tomato',
#  'cherry tomato grapes',
#  'cherry tomato heirloom tomato',
#  'cherry tomato large tomato',
#  'chhedar cheese ed',
#  'chia seeds',
#  'chia seeds flax seeds',
#  'chia seeds nuts',
#  'chia seeds water',
#  'chicken',
#  'chicken bite',
#  'chicken bless',
#  'chicken bless skinless breast piece angular',
#  ...]

# %%
ingredients_list
# Out:
# ['',
#  ' ) plus cherries stems',
#  ' * es',
#  ' after ing',
#  ' b',
#  ' banana replace eggs',
#  ' based on its strength',
#  ' black pepper',
#  ' brush prep',
#  ' byadgi : guntur',
#  ' can',
#  ' can also be used not vegan',
#  ' canned',
#  ' canola vegetable oil',
#  ' case you intend not pineapple juice',
#  ' change water everyday',
#  ' coffee beans',
#  ' consistency',
#  ' cooled',
#  ' corn meal',
#  ' depending on the pungency',
#  ' diameter',
#  ' dried parsley used',
#  ' dried tarragon used',
#  ' es',
#  ' fillet',
#  ' flavour ',
#  ' flour',
#  ' gram',
#  ' guavas them grinder',
#  ' kids crowd sweet tooth',
#  ' large bajji chilli green bell peppers',
#  ' large packs',
#  ' lemon size',
#  ' less based on the spice level desired',
#  ' make dosa',
#  ' making the paste the amount mustard used ',
#  ' millet',
#  ' ml',
#  ' months above',
#  ' needed',
#  ' not season',
#  ' number pan',
#  ' nutmeg',
#  ' only',
#  ' oz',
#  ' packet',
#  ' pearl millet',
#  ' pepper',
#  ' per preference',
#  ' per spice preference',
#  ' preferably',
#  ' preference',
#  ' quantity ',
#  ' recipe portions',
#  ' reduce ',
#  ' rice',
#  ' rice variety',
#  ' ripen totapuri cultivar',
#  ' sheets',
#  ' size',
#  ' slices',
#  ' spice',
#  " spinach you don'have",
#  ' strand',
#  ' strips',
#  ' such are needed',
#  ' sugar',
#  ' suit spice levels',
#  ' sweetness mangoes',
#  ' th',
#  ' than ',
#  ' the amount ',
#  ' the heat the chillies',
#  ' the number chillies spice level',
#  ' the tartness mangoes',
#  ' tolerance',
#  ' tuna from standard tin',
#  ' using mortar pestle',
#  ' virgin',
#  ' vivatta wheat flour chakki atta',
#  ' whistles',
#  ' you can an oil spray',
#  ' you can grate nutmeg directly on the filling',
#  ' you like spicy',
#  '%',
#  '(',
#  '(amul',
#  '(or milk',
#  '(or nondairy',
#  ')',
#  ') sour',
#  'aachi fish masala',
#  'aam papad',
#  'aamras',
#  'aar maach',
#  'achari masala',
#  'achari mayo',
#  'achari mayo drizzling on top',
#  'achari mayo tikki',
#  'acorn squash',
#  'ada',
#  'adobo sauce',
#  'aerated water',
#  'agar agar',
#  'agar agar gelatin',
#  'agar agar strands',
#  'agathi keerai',
#  'agave nectar',
#  'agavemaple syrup',
#  'ajwain',
#  'alfalfa powder',
#  'alfalfa sprouts',
#  'alkanet) (infuse heated oil',
#  'alkanet) infuse heated oil',
#  'alkanet) infused oil',
#  'almond',
#  'almond butter',
#  'almond butter peanut butter',
#  'almond essence',
#  'almond meal',
#  'almond milk',
#  'almond milk (badam milk',
#  'almond milk (badam milk frothed',
#  'almond milk (badam milk unsweetened',
#  'almond milk (badam milk water',
#  'almond milk water',
#  'almond oil',
#  'almond pistachios',
#  'almond silver',
#  'almond) ( smoked',
#  'almond) (can be substituted other nuts',
#  'almond) (grind almonds mixer grinder speed',
#  'almond) (preferably ',
#  'almond) a',
#  'almond) flaked',
#  'almond) flaxes',
#  'almond) ground powder',
#  'almond) light',
#  'almond) macadamia nuts',
#  'almond) paste',
#  'almond) pistachios',
#  'almond) pistachois will also do',
#  'almond) pound',
#  'almond) roast ground',
#  'almond) salted',
#  'almond) silvered',
#  'almond) skin',
#  'almond) soak water the skin',
#  'almond) walnuts',
#  'almonds',
#  'almonds cashew nuts pistachios',
#  'almonds cashewnuts',
#  'almonds pistachios',
#  'almonds soak',
#  'aloe vera',
#  'aloo',
#  'aloo bhujia',
#  'aloo tikki',
#  'aloo) (or sweet potato',
#  'aloo) a the skin (do not boil them too soft',
#  'aloo) baby potatoes',
#  'aloo) banana',
#  'aloo) barrel shape',
#  'aloo) bitesize',
#  'aloo) boiled',
#  'aloo) cm cubes',
#  'aloo) cubes',
#  'aloo) fingers',
#  'aloo) firm',
#  'aloo) fries',
#  'aloo) large cubes',
#  'aloo) paper',
#  'aloo) pealed',
#  'aloo) pressure',
#  'aloo) salt water',
#  'aloo) skin',
#  'aloo) skin pound',
#  'aloo) straws',
#  'aloo) the potatoes',
#  'aloo) the skin large cubes',
#  'also works',
#  'alu bukhara',
#  'amaranth flour',
#  'amaranth flour) binding',
#  'amaranth leaves',
#  'amaranth seeds',
#  'amchoor',
#  'amchoor powder',
#  'amchoor powder per requirement',
#  'amchur',
#  'amchur lemon',
#  'amchur powder',
#  'amla',
#  'amla size',
#  'amtekai',
#  'amtekai) (ambade',
#  'amul',
#  'amul brand',
#  'anardana powder',
#  'and ',
#  'aniseed',
#  'any local variety',
#  'any variety',
#  'appe midi',
#  'apple',
#  'apple (',
#  'apple chickoo',
#  'apple cider vinegar',
#  'apple cider vinegar vinegar',
#  'apple cider vinegar white vinegar',
#  'apple cored',
#  'apple cored spiralized noodles',
#  'apple crescent shaped',
#  'apple gourd',
#  'apple juice',
#  'apple julienne',
#  'apple matchstickthin',
#  'apple vodka',
#  'apples',
#  'apples apples',
#  'apples cored',
#  'applewithout',
#  'apricots',
#  'apricots dried',
#  'apricots drieds',
#  'arabic',
#  'arabic leaves',
#  'arabic now',
#  'arabica',
#  'aralu',
#  'arbi',
#  'arbi) destemmed',
#  'arbi) leaves a tender stems',
#  'arbi) skin',
#  'arbi) tho',
#  'arbi)like fries',
#  'arborio rice',
#  'arhar dal',
#  'arhar dal moong dal',
#  'arhar dal soak',
#  'arisithipli',
#  'around beets',
#  'around gm',
#  'arrowroot flour',
#  'arrowroot flour corn flour',
#  'artichokes',
#  'artichokes tinned artichokes',
#  'arugula leaves',
#  'arugula leaves roots',
#  'asafetida',
#  'asafoetida',
#  'ash gourd chips',
#  'ash gourdwhite pumpkin',
#  'ash gourdwhite pumpkin) de skinned',
#  'ash gourdwhite pumpkin) seeds skin',
#  'ash gourdwhite pumpkin) skin',
#  'asian',
#  'asian sea bass',
#  'asian style',
#  'asparagus',
#  'asparagus stem',
#  'assam tea leaves',
#  'assorted colors',
#  'at ',
#  'atta',
#  'aubergine',
#  'avarekai',
#  'avarekalu lilva beans',
#  'avarekalu lilva beans field beans',
#  'avarekalu lilva beans pressure',
#  'avarekalu lilva beans skin',
#  'avarekalu lilva beans stringed',
#  'avocado',
#  'avocado bite just before',
#  'avocado fork',
#  'avocado fully ripe',
#  'avocado pulped',
#  'avocado ripe',
#  'avocado ripen',
#  'avocado ripened',
#  'avocado skin',
#  'avocados',
#  'avocados ripe',
#  'avocados ripened',
#  'avrekalu',
#  'azuki',
#  'baby corn',
#  'baby corn (if using',
#  'baby corn approximately',
#  'baby corn baby corn',
#  'baby corn be',
#  'baby corn take',
#  'baby potatoes',
#  'baby potatoes potato',
#  'baby potatoes quatered',
#  'baby potatoes skin',
#  'baby spinach',
#  'baby spinach salad leaves',
#  'baby spinach tore',
#  'bacon',
#  'bacon smoked',
#  'badam',
#  'badam essence',
#  'badam milk coconut milk (ly cted',
#  'badam oil',
#  'badam powder',
#  'badam) a',
#  'badam) almonds',
#  'badam) pista cashews',
#  'badam) pound',
#  'badam) walnuts',
#  'badi',
#  'badi elaichi',
#  'badi hari mirch',
#  'bael fruit',
#  'bagel',
#  'baguette',
#  'baguette wheat',
#  'baileys irish',
#  'baingan eggsplant',
#  'baingan eggsplant) ( variety',
#  'baingan eggsplant) (crown each',
#  'baingan eggsplant) (cut slices',
#  'baingan eggsplant) (into ',
#  'baingan eggsplant) (use smer brinjals elevated ',
#  'baingan eggsplant) cm cubes',
#  'baingan eggsplant) destemmed',
#  'baingan eggsplant) diagonal',
#  'baingan eggsplant) dices',
#  'baingan eggsplant) from top stuffing',
#  'baingan eggsplant) green seedless variety',
#  'baingan eggsplant) make',
#  'baingan eggsplant) mm (lengthwise',
#  'baingan eggsplant) ness',
#  'baingan eggsplant) purple',
#  'baingan eggsplant) quatered',
#  'baingan eggsplant) salt water',
#  'baingan eggsplant) stalks',
#  'baingan eggsplant) three',
#  'baingan eggsplant)(use the regular eggsplant not the used baingan bhartha',
#  'bajji variety (light green s',
#  'bajra',
#  'bajra dosa batter',
#  'bajra flour',
#  'baked beans',
#  'baked beans can',
#  'baked beans tin',
#  'baking powder',
#  'baking powder eggs',
#  'baking powder heaped',
#  'baking soda',
#  'baking soda generous',
#  'baking soda heaped',
#  'balsamic vinegar',
#  'balsamic vinegar red wine vinaigrette',
#  'bamboo shoots',
#  'banana',
#  'banana boil',
#  'banana cubes',
#  'banana dices',
#  'banana flower',
#  'banana leaf',
#  'banana leaf cook',
#  'banana leaf line the steamer',
#  'banana leaf toss heat them squares remove the stem',
#  'banana leaf wrap the fish',
#  'banana leaves cook on low flame',
#  'banana leaves steamer put',
#  'banana skin',
#  'banana stem',
#  'banana stem butter milk',
#  'banana stem buttermilk',
#  'banana stem dices',
#  'banana stem dices buttermilk',
#  'banana stem outer layer',
#  'banana stem skin',
#  'banana stemand',
#  'bananas',
#  'bananas caramelised',
#  'bananas cubes',
#  'bananas diagonal',
#  'bananas fork',
#  'bananas fully ripe',
#  'bananas heaped',
#  'bananas nendra variety',
#  'bananas ripe',
#  'bananas robusta variety',
#  'bananas slice top',
#  'bananas spotty',
#  'bananas the elaichi banana variety',
#  'bangada fish',
#  'barbeque masala',
#  'barbeque sauce',
#  'barbeque sauce bottle jerk barbecue sauce',
#  'barley',
#  'barley flour',
#  'barnyard millet',
#  'barnyard millet variety',
#  'barramundiasian sea bass',
#  'basa fish',
#  'basa fish bless skinless',
#  'basa fish fillet',
#  'basa fish fillets',
#  'basa fish finger length',
#  'basa fish salmon white firm fleshed fish',
#  'basella',
#  'basil',
#  'basil leaves',
#  'basil leaves chiffonade',
#  'basil leaves dried',
#  'basil leaves dried basil',
#  'basil leaves dry',
#  'basil leaves ground paste',
#  'basil leaves kaffir lime leaves',
#  'basil leaves leaves',
#  'basil leaves loosely packed',
#  'basil leaves oregano',
#  'basil leaves prepared earlier',
#  'basil leaves rolled',
#  'basil leaves sniped',
#  'basil leaves take out the stem',
#  'basil leaves the curry',
#  'basil leaves y',
#  'basil pesto',
#  'basil pesto basil pesto',
#  'basil powder oregano',
#  'basmati rice',
#  'basmati rice drain the water',
#  'basmati rice enough water',
#  'basmati rice fragrant rice',
#  'basmati rice gobindo bhog rice',
#  'basmati rice govind bhog rice',
#  'basmati rice grain',
#  'basmati rice grain rice',
#  'basmati rice ground',
#  'basmati rice hour',
#  'basmati rice least',
#  'basmati rice min',
#  'basmati rice mins',
#  'basmati rice soak',
#  'basmati rice spices infused water (spices include cinnamon',
#  'basmati rice white rice; we can substitute this brown rice',
#  'bathua leaves',
#  'batua',
#  'bay leaf',
#  'bay leaf break',
#  'bay leaf break take',
#  'bay leaves',
#  'bay leaves bay leaves',
#  'bc belle bhat powder',
#  'bean paste',
#  'bean sprouts',
#  'beef',
#  'beer',
#  'beetroot',
#  'beetroot centimeter',
#  'beetroot dices',
#  'beetroot greens',
#  'beetroot juice',
#  'beetroot juiced',
#  'beetroot spiralized noodles',
#  'beetroots',
#  'bengal gram dal',
#  'bengal gram dal) (for hour',
#  'bengal gram dal) atleast',
#  'bengal gram dal) fro',
#  'bengal gram dal) ground',
#  'bengal gram dal) hour',
#  'bengal gram dal) least',
#  'bengal gram dal) min',
#  'bengal gram dal) mins',
#  'bengal gram dal) split',
#  'ber stems',
#  'besan',
#  'besan) (besan',
#  'besan) besan',
#  'besan) cardamom powder â\x80\x93 tsp',
#  'besan) dry',
#  'besan) handwa flour mix',
#  'besan) salt',
#  'best french bread',
#  'betel leaves',
#  'betel nut',
#  'bhagar flour',
#  'bhaja masala',
#  'bhakarwdis',
#  'bhang paste',
#  'bhetki fish',
#  'bhetki fish fillets',
#  'bhindi',
#  'bhindiokravendaikkai',
#  'bhut jolokia',
#  'bilimbi',
#  'bimbla',
#  'bird lime',
#  'birds eye chilli',
#  'birds eye chilli) regular green chillies',
#  "birds eye chilli)(if you don'find birds eye chillies",
#  'biryani masala',
#  'biryani masala powder',
#  'bisi bele bhat spice powder',
#  'bisleri fonzo the bubbly mango drink',
#  'bitter gourd',
#  'bitter gourd after removing seeds',
#  'bitter gourd pavakkai',
#  'bitter gourd pavakkai) cylindrical',
#  'bitter gourd pavakkai) de skinned',
#  'bitter gourd pavakkai) dices (remove excess seeds from inside',
#  'bitter gourd pavakkai) scraped',
#  'bitter gourd pavakkai) seeds',
#  'bitter gourd pavakkai) tender',
#  'bitter sweet chocolate',
#  'black beans',
#  'black beans canned',
#  'black beans sauce',
#  'black cardamom',
#  'black chilli powder',
#  'black cumin',
#  'black currant ice',
#  'black eyed beans',
#  'black gram',
#  'black gram soak cook till becomes soft',
#  'black gram sprouted',
#  'black grapes',
#  'black grapes juice',
#  'black olives',
#  'black olives both green black',
#  'black pepper',
#  'black pepper corns',
#  'black pepper corns forr',
#  'black pepper corns ground',
#  'black pepper grind',
#  'black pepper powder',
#  'black pepper powder black pepper powder',
#  'black pepper powder cracked',
#  'black pepper powder grind',
#  'black pepper powder ground',
#  'black pepper powder paprika',
#  'black pepper powder pound',
#  'black pepper powder red chilli powder',
#  'black pepper powder wise',
#  'black pepper powderblack pepper powder',
#  'black peppercorns',
#  'black peppercorns cracked',
#  'black peppercorns ground',
#  'black peppercorns mortar pestle',
#  'black peppercorns pound',
#  'black peppercorns thawed',
#  'black peppercorns y',
#  'black peppers',
#  'black plum',
#  'black raisins',
#  'black rice',
#  'black rice seasd salt',
#  'black salt',
#  'black salt salt',
#  'black salt white salt',
#  'black sesame seeds',
#  'black sesame seeds sprinkling',
#  'black sesame seeds white sesame seeds',
#  'black soy beans',
#  'black tea bag',
#  'black tea leaves',
#  'black urad dal',
#  'black urad dal ground make atta',
#  'black variety',
#  'blackberries berries',
#  'blackberries other berries',
#  'bless',
#  'bless) cubes',
#  'blueberries',
#  'blueberries dry',
#  'blueberries locy available berries',
#  'blueberries locy available berry',
#  'blueberries other berry season',
#  'blueberry jam',
#  'bocconcini cheese halves',
#  'boiled eggs',
#  'boiled peanuts',
#  'bok choy',
#  'bok choy heads',
#  'boneless chicken',
#  'boneless chicken (',
#  'boneless chicken boneless chicken â\x80\x93 gms',
#  'boneless chicken breasts',
#  'boneless chicken cubes',
#  'boneless chicken miced',
#  'boneless chicken uniform',
#  'boondi',
#  'boondi kara boondi',
#  'boondi masala',
#  'boondi masala boondi',
#  'boondi sev',
#  'boondi spicy',
#  'botis golden finger fryums',
#  'bottle gourd',
#  'bourbon',
#  'bourbon biscuits',
#  'bourbon biscuits other biscuits',
#  'bournville rich cocoa from india works fantastic',
#  'brahmi leaves',
#  'branch coriander',
#  'brandy',
#  'bread',
#  'bread crumbs',
#  'bread cubes',
#  'breads',
#  'brie cheese',
#  'brinjal',
#  'brinjals',
#  'britannia',
#  'britannia cheese asli pepper',
#  'britannia cheese block',
#  'britannia cheese classic',
#  'britannia cheese cubes',
#  'britannia cheese four pepper tango',
#  'britannia cheese garlic',
#  'britannia cheese mexican chilli',
#  'britannia cheese peppy pizza',
#  'britannia cheese slice',
#  'britannia cheezza',
#  'broad beans',
#  'broad beans) st cut.',
#  'broccoli',
#  'broccoli bite florets',
#  'broccoli cauliflower florets',
#  'broccoli florets',
#  'broccoli florets approximately',
#  'broccoli florets blitzed',
#  'broccoli flowerets',
#  'broccoli smer',
#  'broccoli smer florets',
#  'broccoli stems',
#  'broccoli tiny florets',
#  'broccolis',
#  'brown cardamom',
#  'brown chickpeas',
#  'brown chickpeas) moong beans',
#  'brown chickpeas) over night',
#  'brown chickpeas) pressure till',
#  'brown chickpeas) sprouted',
#  'brown chickpeas) you get the green variety',
#  'brown rice',
#  'brown rice beforehand',
#  'brown rice flakes',
#  'brown rice poha',
#  'brown sugar',
#  'brussel sprouts',
#  'buckwheat flour',
#  'bud',
#  'bud garlic',
#  'bud garlic paste',
#  'buds garlic',
#  'buds garlic finely',
#  'bulb greens',
#  'bulb greens) (including greens bulbs',
#  'bulb greens) (white greens',
#  'bulb greens) (white top part',
#  'bulb greens) both green white',
#  'bulb greens) bulbs',
#  'bulb greens) bunch',
#  'bulb greens) green bulbs',
#  'bulb greens) leaves',
#  'bulb greens)(or regular onion',
#  'bulb greens)with leaves',
#  'bulb greens)with the bulb leaves kept separate',
#  'bulgur wheat',
#  'bulgur wheat organic',
#  'bunch arugula leaves',
#  'burger buns',
#  'burger buns masala buns',
#  'burger buns mini',
#  'burger buns sliders',
#  'burger buns wheat',
#  'but normal can be used)',
#  'butter',
#  'butter apply on bread',
#  'butter apply on pinwheels',
#  'butter baking',
#  'butter baste',
#  'butter brushing',
#  'butter clarified',
#  'butter coconut butter',
#  'butter coconut oil',
#  'butter cold',
#  'butter cold divided',
#  'butter cold pea',
#  'butter cold unsalted',
#  'butter cooled',
#  'butter cubes',
#  'butter divided',
#  'butter ghee',
#  'butter ghee brushing',
#  'butter gheeoil',
#  'butter grease',
#  'butter grease the pan',
#  'butter grease the tintray',
#  'butter grease waffle iron',
#  'butter greasing',
#  'butter greasing naan',
#  'butter greasing the baking dish',
#  'butter greasing the pan',
#  'butter grilling',
#  'butter have used salted butter',
#  'butter loni',
#  'butter make pancakes',
#  'butter oil',
#  'butter oil grease',
#  'butter oil mixed',
#  'butter oil pancakes',
#  'butter oil the filling',
#  'butter olive oil',
#  'butter olive oil brushing the rotis',
#  'butter olive oil grease',
#  'butter on the naans',
#  'butter pan',
#  'butter pea',
#  'butter per sandwich',
#  'butter plus',
#  'butter plus pan',
#  'butter ricotta cheese',
#  'butter roasting the pizza base',
#  'butter room temprature',
#  'butter salted',
#  'butter salted unsalted',
#  'butter sandwich',
#  'butter sizzling',
#  'butter some finishing',
#  'butter stick',
#  'butter temperature be kept cold',
#  'butter the kulchas',
#  'butter the toast',
#  'butter toasting',
#  'butter toasting pita',
#  'butter toasting the bread',
#  'butter toasting the buns',
#  'butter toasting the burger buns',
#  'butter unsalted',
#  'butter vegan version coconut oil',
#  'butter vegetable oil',
#  'butterapproximately',
#  'butterbutter',
#  'buttermilk',
#  'buttermilk amsul',
#  'buttermilk cold',
#  'buttermilk sour',
#  'buttermilk strained remove lumps',
#  'butternut squash seeded',
#  'butterof butter',
#  'butterscotch chips',
#  'butterscotch chips almonds',
#  'butterscotch ice',
#  'button crimini variety',
#  'button mushroom',
#  'button mushrooms',
#  'button mushrooms (you can alternatively combination vegetables like beans',
#  'button mushrooms cremini mushrooms',
#  'button mushrooms destemmed',
#  'button mushrooms large',
#  'button mushrooms large portobello mushroom',
#  'button mushrooms mushroom',
#  'button mushrooms portabello mushrooms',
#  'button mushrooms sautÃ©ed',
#  'button mushrooms shopped',
#  'button mushrooms stem',
#  'byadagi chilli powder',
#  'byadagi dried chillies',
#  'byadagi dried chillies water',
#  'byadagi dried chillies you can kashmiri chillies red chillies)',
#  'c',
#  'cabbage',
#  'cabbage leaves',
#  'cabbage spoon',
#  'cajun spice mix',
#  'cajun spice mix chutney podi sprinkling on top',
#  'cake candy s',
#  'cake candy s) (preferably',
#  'cake candy s) decorate',
#  'cake candy s) decorating',
#  'cake mix used pillsbury vanilla cake mix',
#  'can bamboo',
#  'can be substituted smoked paprika',
#  'can condensed milk',
#  'can using oregano',
#  'candied orange',
#  'candy sugar',
#  'cane sugar',
#  'cane sugar coconut sugar',
#  'canned',
#  'canned beans',
#  'canned black beans',
#  'canned cherries',
#  'canned cherries available cherries',
#  'canned cherries garnsh',
#  'canned storebought mushrooms',
#  'canned tuna',
#  'canola oil',
#  'canola oil flavorless oil',
#  'canola oil olive oil',
#  'canola oil pan masoor dal fritters',
#  'cape gooseberries husk',
#  'capers',
#  'capsicum',
#  'capsicum) (',
#  'capsicum) ( each',
#  'capsicum) (or other vegetables that can be stir ',
#  'capsicum) bitesize',
#  'capsicum) colour',
#  'capsicum) cubes',
#  'capsicum) diagonal',
#  'capsicum) diamond',
#  'capsicum) fire',
#  'capsicum) green',
#  'capsicum) green capsicum',
#  'capsicum) julienne',
#  'capsicum) jullienes',
#  'capsicum) large squares',
#  'capsicum) larger',
#  'capsicum) red',
#  'capsicum) red bell peppers',
#  'capsicum) red yellow',
#  'capsicum) smer',
#  'capsicum) squares',
#  'capsicum) stir',
#  'capsicum) yellow',
#  'capsicum)lengthwise',
#  'caramel sauce',
#  'caramelize',
#  'cardamom',
#  'cardamom break',
#  'cardamom crush',
#  'cardamom grind',
#  'cardamom powder',
#  'cardamom powder grind',
#  'carom seeds',
#  'carom seeds) (shahi jeera',
#  'carom seeds) between palms',
#  'carom seeds) cumin seeds',
#  'carom seeds) pound',
#  'carom seeds) powder',
#  'carom seeds) sesame seeds',
#  'carrot',
#  'carrot approximately â\x80\x9d',
#  'carrot beans peas',
#  'carrot bitesize',
#  'carrot cake recipe leftover',
#  'carrot carrot',
#  'carrot centimetre cubes',
#  'carrot circles',
#  'carrot coins',
#  'carrot cubes',
#  'carrot dices',
#  'carrot finger coins',
#  'carrot julianne',
#  'carrot julienne',
#  'carrot matchsticks',
#  'carrot ness',
#  'carrot pelled',
#  'carrot red',
#  'carrot skin',
#  'carrot spiralized noodles',
#  'carrot sticks',
#  'carrot veticy',
#  'carrotinto',
#  'carrotor',
#  'cashew',
#  'cashew nuts',
#  'cashew nuts approximately',
#  'cashew nuts cashew nuts',
#  'cashew nuts decoration',
#  'cashew nuts ghee',
#  'cashew nuts ghee ed',
#  'cashew nuts glass water',
#  'cashew nuts ground',
#  'cashew nuts ground paste',
#  'cashew nuts ground smooth paste',
#  'cashew nuts ground smooth paste water',
#  'cashew nuts hour minimum',
#  'cashew nuts least',
#  'cashew nuts paste',
#  'cashew nuts peanuts',
#  'cashew nuts soak water grind',
#  'cashew nuts split',
#  'cashew nuts unsalted',
#  'cashew nuts water',
#  'cashew nuts water salt',
#  'cashew peanuts',
#  'cashews',
#  'cashews almonds',
#  'cashews ground',
#  'cashews ground paste',
#  'cashews soak water',
#  'cashews some',
#  'cashews water',
#  'cassia',
#  'cast coriander',
#  'caster sugar',
#  'caster sugar a',
#  'caster sugar brown sugar',
#  'caster sugar divided',
#  'caster sugar garnsih',
#  'caster sugar superfine',
#  'cauliflower',
#  'cauliflower leaves',
#  'cawanprash',
#  'cayenne pepper',
#  'cayenne pepper ground',
#  'cayenne pepper red chilli powder',
#  'celery',
#  'celery between the palm',
#  'celery stalks',
#  'celery stick',
#  'cereal',
#  'chaat masala powder',
#  'chaat masala powder powder',
#  'chaat masala powder the end',
#  'chai masala',
#  'chakra flowers',
#  'chakundar',
#  'chamomile tea brewed',
#  'champagne sparkling wine',
#  'chana dal',
#  'chana lentils',
#  'chana masala powder',
#  'chana stock',
#  'chandi ka vark',
#  'chandi ka vark) edible',
#  "chandi'work eater",
#  'char magaz',
#  'charcoal',
#  'charcoal dum',
#  'charcoal piece',
#  'charcoal smoke',
#  'charcoal smoking',
#  'chavli',
#  'chayote',
#  'chayote skin',
#  'chayote squash',
#  'chayote squash) cored',
#  'cheddar cheese',
#  'cheddar cheese aged',
#  'cheddar cheese cheese',
#  'cheddar cheese cubes',
#  'cheddar cheese mexican cheese',
#  'cheddar cheese mozzarella cheese',
#  'cheddar cheese paneer',
#  'cheddar cheese sharp',
#  'cheddar cheese topping',
#  'cheddar mexican cheese',
#  'cheddar parmesan',
#  'cheese',
#  'cheese (flavored',
#  'cheese (use britannia',
#  "cheese britannia'classic cheese z",
#  'cheese chaat masala powder',
#  'cheese cheese',
#  'cheese cheese cheese',
#  'cheese crumble',
#  'cheese cubes',
#  'cheese flavored like jalepeno peppers works great',
#  'cheese flavoured',
#  'cheese frosting',
#  'cheese over the bread',
#  'cheese pepper',
#  'cheese pepper flavour prefered',
#  'cheese per tasete',
#  'cheese philadelphia)',
#  'cheese plus topping',
#  'cheese processed',
#  'cheese processed chees',
#  'cheese slice',
#  'cheese soft paneer',
#  'cheese you can do take paneer salt grind mixer',
#  'cheese you find difficult get',
#  'cheese)',
#  'cheesehua pepper powder',
#  'cheetos',
#  'chenna',
#  'cherries',
#  'cherries (or fruits whipped',
#  'cherries dried',
#  'cherries stem',
#  'cherries strawberries',
#  'cherry compote',
#  'cherry preserve jam glazing',
#  'cherry tomato',
#  'cherry tomato (or large tomato',
#  'cherry tomato grapes',
#  'cherry tomato heirloom tomato',
#  'cherry tomato large tomato',
#  'chhedar cheese ed',
#  'chia seeds',
#  'chia seeds flax seeds',
#  'chia seeds nuts',
#  'chia seeds water',
#  'chicken',
#  'chicken bite',
#  'chicken bless',
#  'chicken bless skinless breast piece angular',
#  ...]

# %%
df1['ingredient_list']
# Out:
# 0       [salt, amchur, dry mango powder, karela, bitte...
# 1       [tomato, salt, chickpea lentils, green chilli,...
# 2       [salt, rice vermicelli noodles, thin, asafoeti...
# 3       [tomato, salt, ginger, sorrel leaves, gongura,...
# 4       [tomato, salt, ginger, red chillies, curry, as...
#                               ...
# 5933    [saffron strands generous, ghee, paneer, rose ...
# 5934    [salt, gorgonzola cheese cubes, wheat bread cr...
# 5935    [ghee, milk, saffron strands, sugar, cardamom ...
# 5936    [salt, tamarind water, mustard seeds, asafoeti...
# 5937    [black cardamom, badi elaichi, salt, mustard o...
# Name: ingredient_list, Length: 5938, dtype: object

# %%
df1['ingredient_list']
# Out:
# 0       [salt, amchur, dry mango powder, karela, bitte...
# 1       [tomato, salt, chickpea lentils, green chilli,...
# 2       [salt, rice vermicelli noodles, thin, asafoeti...
# 3       [tomato, salt, ginger, sorrel leaves, gongura,...
# 4       [tomato, salt, ginger, red chillies, curry, as...
#                               ...
# 5933    [saffron strands generous, ghee, paneer, rose ...
# 5934    [salt, gorgonzola cheese cubes, wheat bread cr...
# 5935    [ghee, milk, saffron strands, sugar, cardamom ...
# 5936    [salt, tamarind water, mustard seeds, asafoeti...
# 5937    [black cardamom, badi elaichi, salt, mustard o...
# Name: ingredient_list, Length: 5938, dtype: object

# %%
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity

# Sample dataset of recipes (ingredients are already tokenized)

        
# Train Word2Vec model on the recipes
model = Word2Vec(sentences=df1['ingredient_list'], vector_size=10, window=3, min_count=1, workers=4)

# Function to calculate cosine similarity between two ingredients
def ingredient_similarity(ingredient1, ingredient2):
    if ingredient1 in model.wv and ingredient2 in model.wv:
        vector1 = model.wv[ingredient1]
        print(ingredient1)
        print(vector1)
        vector2 = model.wv[ingredient2]
        print(ingredient2)
        print(vector2)
        similarity = cosine_similarity([vector1], [vector2])[0][0]
        return similarity
    else:
        return None

# Example usage
ingredient1 = 'chilli'
ingredient2 = 'sugar'
similarity_score = ingredient_similarity(ingredient1, ingredient2)

if similarity_score is not None:
    print(f"Similarity between '{ingredient1}' and '{ingredient2}': {similarity_score}")
else:
    print("One or both ingredients not found in the model vocabulary.")
# Out:
# One or both ingredients not found in the model vocabulary.

# %%
import numpy as np
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from keras.preprocessing.sequence import pad_sequences

# Sample dataset of recipes (ingredients are already tokenized)
ingredients_corpus = df1['ingredient_list']

# Train Word2Vec model on the recipes
word2vec_model = Word2Vec(sentences=ingredients_corpus, vector_size=100, window=3, min_count=1, workers=4)

# Create word-to-index mapping for LSTM
word_to_index = {word: idx + 1 for idx, word in enumerate(set(sum(ingredients_corpus, [])))}
index_to_word = {idx: word for word, idx in word_to_index.items()}
vocab_size = len(word_to_index) + 1  # Add one for the padding token

# Define the LSTM model
max_len = max(len(seq) for seq in ingredients_corpus)
lstm_model = Sequential()
lstm_model.add(Embedding(input_dim=vocab_size, output_dim=100, input_length=max_len, mask_zero=True))  # Mask zero for padding
lstm_model.add(LSTM(128))
lstm_model.add(Dense(100))  # Output dimension same as Word2Vec vectors

lstm_model.compile(loss='mse', optimizer='adam')

# Function to generate word vector using Word2Vec or LSTM
def generate_word_vector(ingredient_text, word2vec_model, lstm_model, max_len, word_to_index):
    if ingredient_text in word2vec_model.wv:
        return word2vec_model.wv[ingredient_text]
    else:
        ingredient_seq = [word_to_index.get(word, 0) for word in ingredient_text.split()]  # Use 0 for OOV words
        ingredient_pad = pad_sequences([ingredient_seq], maxlen=max_len)
        word_vector = lstm_model.predict(ingredient_pad).squeeze()  # Remove singleton dimensions
        return word_vector

# Function to calculate cosine similarity between two ingredients
def ingredient_similarity(ingredient1, ingredient2, word2vec_model, lstm_model, max_len, word_to_index):
    # Check if ingredient1 is present in Word2Vec vocabulary
    if ingredient1 in word2vec_model.wv:
        vector1 = word2vec_model.wv[ingredient1]
    else:
        # Generate word vector using LSTM model
        vector1 = generate_word_vector(ingredient1, word2vec_model, lstm_model, max_len, word_to_index)
    
    
    # Check if ingredient2 is present in Word2Vec vocabulary
    if ingredient2 in word2vec_model.wv:
        vector2 = word2vec_model.wv[ingredient2]
    else:
        # Generate word vector using LSTM model
        vector2 = generate_word_vector(ingredient2, word2vec_model, lstm_model, max_len, word_to_index)
    
    
    # Calculate cosine similarity
    similarity = cosine_similarity([vector1], [vector2])[0][0]
    return similarity

# Example usage
ingredient1 = 'vanilla'
ingredient2 = 'sugar'
similarity_score = ingredient_similarity(ingredient1, ingredient2, word2vec_model, lstm_model, max_len, word_to_index)

print(f"Similarity between '{ingredient1}' and '{ingredient2}': {similarity_score}")
# Out:
# Similarity between 'vanilla' and 'sugar': 0.9092568755149841
# C:\Users\admin\anaconda3\lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
from itertools import combinations
threshold=0.6
def ingredient_similarity_list(ingredients):
    similarity_scores = {}
    for pair in combinations(ingredients, 2):
        ingredient1, ingredient2 = pair
        if ingredient1 in model.wv and ingredient2 in model.wv:
            vector1 = model.wv[ingredient1]
            vector2 = model.wv[ingredient2]
            similarity = cosine_similarity([vector1], [vector2])[0][0]
            if similarity > threshold:
                similarity_scores[(ingredient1, ingredient2)] = similarity
        else:
            similarity_scores[(ingredient1, ingredient2)] = None
    return similarity_scores

# Example usage
ingredient_list = ['vermicelli', 'sugar', 'salt','milk']
similarity_scores = ingredient_similarity_list(ingredient_list)

for (ingredient1, ingredient2), similarity_score in similarity_scores.items():
    if similarity_score is not None:
        print(f"Similarity between '{ingredient1}' and '{ingredient2}': {similarity_score}")
    else:
        print(f"One or both ingredients '{ingredient1}' and '{ingredient2}' not found in the model vocabulary.")
# Out:
# Similarity between 'vermicelli' and 'sugar': 0.8969341516494751
# Similarity between 'vermicelli' and 'salt': 0.6077505350112915
# Similarity between 'vermicelli' and 'milk': 0.7814439535140991
# Similarity between 'sugar' and 'milk': 0.8532429933547974
# Similarity between 'salt' and 'milk': 0.6271592378616333
